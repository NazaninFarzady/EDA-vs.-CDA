# %% [markdown]
# <a href="https://colab.research.google.com/github/NazaninFarzady/EDA-vs.-CDA/blob/main/eda_vs_cda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exploratory vs Confirmatory Data Analysis
# ---
#
# In this project, we are going to learn about two important data analysis methods **EDA** (Exploratory Data Analysis) and **CDA** (Confirmatory Data Analysis).

# %% [markdown]
# ### Exploratory Data Analysis (EDA)

# %% [markdown]
# Importing Modules

# %%
# Install and import necessary libraries
# !pip install plotly --upgrade

# Pandas Module
import pandas as pd

# Data Visualization Module
import plotly.express as px
import plotly.graph_objects as go
import plotly.offline as pyo
# %matplotlib inline

# Setting some default settings
pd.set_option('mode.chained_assignment',None)
#pyo.init_notebook_mode()
# Out:
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (5.15.0)
# Collecting plotly
#   Downloading plotly-5.22.0-py3-none-any.whl (16.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 40.3 MB/s eta 0:00:00
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly) (8.4.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly) (24.1)
# Installing collected packages: plotly
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.15.0
#     Uninstalling plotly-5.15.0:
#       Successfully uninstalled plotly-5.15.0
# Successfully installed plotly-5.22.0

# %% [markdown]
# Let's load our dataset

# %%
#read my dataframe
data = pd.read_csv("/content/dataset.csv", engine="python", encoding='latin1')

# %% [markdown]
# If after reading this dataset with the code "pd.read_csv("/content/dataset.csv", engine="python")", it returns "UnicodeDecodeError":
#
# The error indicates that the pandas library is trying to read a CSV file using the default utf-8 encoding, but it encounters a byte sequence (0xa0 in this case) that it cannot decode. This usually happens when the file is encoded in a different encoding.
# To solve this error, one way is using (encoding='latin1') argument

# %% [markdown]
# Checking the data size

# %%
data.shape
# Out:
# (9994, 9)

# %% [markdown]
# Checking the data

# %%
data.head()
# Out:
#    Order Date    Customer Name       State         Category Sub-Category  \
# 0   11/8/2016      Claire Gute    Kentucky        Furniture    Bookcases
# 1   11/8/2016      Claire Gute    Kentucky        Furniture       Chairs
# 2   6/12/2016  Darrin Van Huff  California  Office Supplies       Labels
# 3  10/11/2015   Sean O'Donnell     Florida        Furniture       Tables
# 4  10/11/2015   Sean O'Donnell     Florida  Office Supplies      Storage
#
#                                         Product Name     Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                     Eldon Fold 'N Roll Cart System   22.3680         2
#
#      Profit
# 0   41.9136
# 1  219.5820
# 2    6.8714
# 3 -383.0310
# 4    2.5164

# %% [markdown]
# ### EDA - Roadmap
#
# In this task, we are going to talk about How to start our exploration.
#
#     Different column data types
#     How are the columns related
#     What are the different information in our data
#     Make a list of the information and start from the first

# %% [markdown]
# Now let's start with checking the column data types

# %%
data.dtypes
# Out:
# Order Date        object
# Customer Name     object
# State             object
# Category          object
# Sub-Category      object
# Product Name      object
# Sales            float64
# Quantity           int64
# Profit           float64
# dtype: object

# %% [markdown]
# Now let's talk about what type of information do we have in this data
#
# ### In our data, we have the following information:
#
#     Time Information (Order Data)
#     Customer Information (Customer Name)
#     Place Information (State name)
#     Hierarchical Information about the products (Category, Sub-category, Product Name)
#     Sale Information (sales, profit, quantity)
#
# Now let's start our exploration

# %% [markdown]
# ### Task 3: Data Exploration: Time Information

# %% [markdown]
# What is the timespan of our data?

# %%
data["Order Date"] = pd.to_datetime(data['Order Date'])
from_date = data["Order Date"].min()
to_date = data["Order Date"].max()
print(f"We have sales infromation from {from_date} to {to_date}")
# Out:
# We have sales infromation from 2014-01-03 00:00:00 to 2017-12-30 00:00:00

# %% [markdown]
# Now let's sort our data by the date

# %%
data = data.sort_values(by="Order Date")
data.head()
# Out:
#      Order Date  Customer Name         State         Category Sub-Category  \
# 7980 2014-01-03  Darren Powers         Texas  Office Supplies        Paper
# 739  2014-01-04  Phillina Ober      Illinois  Office Supplies       Labels
# 740  2014-01-04  Phillina Ober      Illinois  Office Supplies      Storage
# 741  2014-01-04  Phillina Ober      Illinois  Office Supplies      Binders
# 1759 2014-01-05     Mick Brown  Pennsylvania  Office Supplies          Art
#
#                                            Product Name    Sales  Quantity  \
# 7980  Message Book, Wirebound, Four 5 1/2" X 4" Form...   16.448         2
# 739                                           Avery 508   11.784         3
# 740                       SAFCO Boltless Steel Shelving  272.736         3
# 741          GBC Standard Plastic Binding Systems Combs    3.540         2
# 1759  Avery Hi-Liter EverBold Pen Style Fluorescent ...   19.536         3
#
#        Profit
# 7980   5.5512
# 739    4.2717
# 740  -64.7748
# 741   -5.4870
# 1759   4.8840

# %% [markdown]
# Some data preparation: let's extract year, month, and day from the Order Date column

# %%
data["Year"] = data["Order Date"].dt.year
data["Month"] = data["Order Date"].dt.month
data["Day"] = data["Order Date"].dt.day
data.head()
# Out:
#      Order Date  Customer Name         State         Category Sub-Category  \
# 7980 2014-01-03  Darren Powers         Texas  Office Supplies        Paper
# 739  2014-01-04  Phillina Ober      Illinois  Office Supplies       Labels
# 740  2014-01-04  Phillina Ober      Illinois  Office Supplies      Storage
# 741  2014-01-04  Phillina Ober      Illinois  Office Supplies      Binders
# 1759 2014-01-05     Mick Brown  Pennsylvania  Office Supplies          Art
#
#                                            Product Name    Sales  Quantity  \
# 7980  Message Book, Wirebound, Four 5 1/2" X 4" Form...   16.448         2
# 739                                           Avery 508   11.784         3
# 740                       SAFCO Boltless Steel Shelving  272.736         3
# 741          GBC Standard Plastic Binding Systems Combs    3.540         2
# 1759  Avery Hi-Liter EverBold Pen Style Fluorescent ...   19.536         3
#
#        Profit  Year  Month  Day
# 7980   5.5512  2014      1    3
# 739    4.2717  2014      1    4
# 740  -64.7748  2014      1    4
# 741   -5.4870  2014      1    4
# 1759   4.8840  2014      1    5

# %% [markdown]
# Show the Profit gained over time by different product categories

# %%
data_time_profit = data.groupby(["Year", "Category"])["Profit"].sum().reset_index()
data_time_profit.head()
# Out:
#    Year         Category      Profit
# 0  2014        Furniture   5457.7255
# 1  2014  Office Supplies  22593.4161
# 2  2014       Technology  21492.8325
# 3  2015        Furniture   3015.2029
# 4  2015  Office Supplies  25099.5338

# %% [markdown]
# Visualizing the results using a line chart

# %%
# prompt: line graph for data_time_profit, x is year, y is profit and color is category

fig = px.line(data_time_profit, x="Year", y="Profit", color="Category", title="Profit Gained Over Time by Product Category")
fig.show()

# If the code above did not show the plot use this: !pip install plotly --upgrade, then run codes and remove the pyo.init_notebook_mode()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.32.0.min.js"></script>                <div id="e3ab58ca-8f4c-444d-ac06-5dd1fdbd9488" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e3ab58ca-8f4c-444d-ac06-5dd1fdbd9488")) {                    Plotly.newPlot(                        "e3ab58ca-8f4c-444d-ac06-5dd1fdbd9488",                        [{"hovertemplate":"Category=Furniture\u003cbr\u003eYear=%{x}\u003cbr\u003eProfit=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Furniture","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Furniture","orientation":"v","showlegend":true,"x":[2014,2015,2016,2017],"xaxis":"x","y":[5457.7255000000005,3015.2028999999998,6959.9531,3018.3913000000002],"yaxis":"y","type":"scatter"},{"hovertemplate":"Category=Office Supplies\u003cbr\u003eYear=%{x}\u003cbr\u003eProfit=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Office Supplies","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Office Supplies","orientation":"v","showlegend":true,"x":[2014,2015,2016,2017],"xaxis":"x","y":[22593.4161,25099.5338,35061.2292,39736.6217],"yaxis":"y","type":"scatter"},{"hovertemplate":"Category=Technology\u003cbr\u003eYear=%{x}\u003cbr\u003eProfit=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Technology","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Technology","orientation":"v","showlegend":true,"x":[2014,2015,2016,2017],"xaxis":"x","y":[21492.8325,33503.867,39773.992,50684.2566],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[ ...

# %% [markdown]
# Here, we can see that the Technology always had the highest amount of profit

# %% [markdown]
# Analyse the monthly profits gained from sales of different product categories. Visualize your results using line chart.

# %%
data_time_month_profit = data.groupby(["Year", "Month", "Category"])["Profit"].sum().reset_index()
data_time_month_profit["Date"] = data_time_month_profit["Year"].astype(str) + "-" + data_time_month_profit["Month"].astype(str)
data_time_month_profit.head()
# Out:
#    Year  Month         Category    Profit    Date
# 0  2014      1        Furniture  805.4665  2014-1
# 1  2014      1  Office Supplies  788.9506  2014-1
# 2  2014      1       Technology  855.7736  2014-1
# 3  2014      2        Furniture  120.6917  2014-2
# 4  2014      2  Office Supplies  176.0910  2014-2

# %%
px.line(data_time_month_profit, x="Date", y="Profit", color="Category", title="Profit Gained Over Time by Product Category")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.32.0.min.js"></script>                <div id="a1af3eb3-701b-46fe-8461-9b6d4cdf8f3f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a1af3eb3-701b-46fe-8461-9b6d4cdf8f3f")) {                    Plotly.newPlot(                        "a1af3eb3-701b-46fe-8461-9b6d4cdf8f3f",                        [{"hovertemplate":"Category=Furniture\u003cbr\u003eDate=%{x}\u003cbr\u003eProfit=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Furniture","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Furniture","orientation":"v","showlegend":true,"x":["2014-1","2014-2","2014-3","2014-4","2014-5","2014-6","2014-7","2014-8","2014-9","2014-10","2014-11","2014-12","2015-1","2015-2","2015-3","2015-4","2015-5","2015-6","2015-7","2015-8","2015-9","2015-10","2015-11","2015-12","2016-1","2016-2","2016-3","2016-4","2016-5","2016-6","2016-7","2016-8","2016-9","2016-10","2016-11","2016-12","2017-1","2017-2","2017-3","2017-4","2017-5","2017-6","2017-7","2017-8","2017-9","2017-10","2017-11","2017-12"],"xaxis":"x","y":[805.4665,120.6917,-1128.655,554.3801,-349.87760000000003,596.3153,374.2467,663.4717,1858.5976,249.1645000000001,-297.89579999999995,2011.8198,-3014.2,394.89480000000003,1455.0573,338.6502,900.5847,-412.6597,-325.0938,-487.4709,1350.1184999999998,-605.5163,2992.0240000000003,428.81409999999994,303.96070000000003,377.03520000000003,-555.268,364.83340000000004,1824.4739,-106.26650000000006,1038.9073,-494.1457,702.6025,-144.65999999999997,819.8088,2828.6715,-39.44019999999996,-199.04210000000003,1000.8532,202.4624,-72.88289999999996,904.9956,324.62440000000004,322.2390000000001,1548.6837,-2526.9203,406.0636999999999,1146.7548000000002],"yaxis":"y","type":"scatter"},{"hovertemplate":"Category=Office Supplies\u003cbr\u003eDate=%{x}\u003cbr\u003eProfit=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Office Supplies","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Office Supplies","orientation":"v","showlegend":true,"x":["2014-1","2014-2","2014-3","2014-4","2014-5","2014-6","2014-7","2014-8","2014-9","2014-10","2014-11","2014-12","2015-1","2015-2","2015-3","2015-4","2015-5","2015-6","2015-7","2015-8","2015-9","2015-10","2015-11","2015-12","2016-1","2016-2","2016-3","2016-4","2016-5","2016-6","2016-7","2016-8","2016-9","2016-10","2016-11","2016-12","2017-1","2017-2","2017-3","2017-4","2017-5","2017-6","2017-7","2017-8","2017-9","2017-10","2017-11","2017-12"],"xaxis":"x","y":[788.9506,176.091,1270.4133,1000.2085999999999,1747.2044,3031.4326,-2482.0172,2767.6007,6699.5401999999995,1117.6406,4411.956,2064.3953,589.8969,1814.1018,5407.848199999999,1477.3596,1731.6139,2195.3864000000003,1113.7829,2208.7531,2037.8836999999999,1090.9375,2800.0289,2631.9409,1604.4712,1330.0009,1061.4056,-1100.4821,2397.5024,2467.4894,1123.9602,1629.1913,3714.0416999999998,4680.055,4686.925,11466.668599999999,3260.4467,953.8253,2715.9624,3370.6015,3153.726,3378.9821,2563.2844999999998,6067.858200000001,4847.7438,4040.7751,3609.1029,1774.3131999999998],"yaxis":"y","type":"scatter"},{"hovertemplate":"Category=Technology\u003cbr\u003eDate=%{x}\u003cbr\u003eProfit=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Technology","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Technology","orientation":"v","showlegend":true,"x":["2014-1","2014-2","2014-3","2014-4","2014-5","2014-6","2014-7","2014-8","2014-9","2014-10","2014-11","2014-12","2015-1","2015-2","2015-3","2015-4","2015-5","2015-6","2015-7","2015-8","2015-9","2015-10","2015-11","2015-12","2016-1","2016-2","2016-3","2016-4","2016-5","2016-6","2016-7","2016-8","2016-9","2016-10","2016-11","2016-12","2 ...

# %% [markdown]
# ### Data Exploration: Customer Aspect

# %% [markdown]
# let's see how many unique costumers do we have

# %%
len(data["Customer Name"].unique())
# Out:
# 793

# %% [markdown]
# let's see the yearly change in number of unique customers

# %%
customer_data = data.groupby("Year")["Customer Name"].nunique().reset_index()
customer_data
# Out:
#    Year  Customer Name
# 0  2014            595
# 1  2015            573
# 2  2016            638
# 3  2017            693

# %% [markdown]
# visualizing the result

# %%
px.line(customer_data, x="Year", y="Customer Name", title="Yearly Change in Number of Unique Customers")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.32.0.min.js"></script>                <div id="09e01bf4-7678-46cf-ab89-678afda48db9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("09e01bf4-7678-46cf-ab89-678afda48db9")) {                    Plotly.newPlot(                        "09e01bf4-7678-46cf-ab89-678afda48db9",                        [{"hovertemplate":"Year=%{x}\u003cbr\u003eCustomer Name=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":[2014,2015,2016,2017],"xaxis":"x","y":[595,573,638,693],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"s ...

# %% [markdown]
# We can see that the busienss was successful because the number of unique customer has increased over the three years

# %% [markdown]
# Top 10 customers who brought the highest profit

# %%
top_ten_customers = data.groupby("Customer Name")["Profit"].sum().reset_index().sort_values(by="Profit", ascending=False).head(10)
top_ten_customers
# Out:
#             Customer Name     Profit
# 730          Tamara Chand  8981.3239
# 622          Raymond Buch  6976.0959
# 671          Sanjit Chand  5757.4119
# 334          Hunter Lopez  5622.4292
# 6           Adrian Barton  5444.8055
# 757          Tom Ashbrook  4703.7883
# 157  Christopher Martinez  3899.8904
# 431         Keith Dawkins  3038.6254
# 35            Andy Reiter  2884.6208
# 194         Daniel Raglin  2869.0760

# %%
px.bar(top_ten_customers, x="Customer Name", y="Profit", title="Top 10 Customers Who Brought the Highest Profit")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.32.0.min.js"></script>                <div id="b9572de7-7585-4ff3-9730-7ca26292635e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b9572de7-7585-4ff3-9730-7ca26292635e")) {                    Plotly.newPlot(                        "b9572de7-7585-4ff3-9730-7ca26292635e",                        [{"alignmentgroup":"True","hovertemplate":"Customer Name=%{x}\u003cbr\u003eProfit=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Tamara Chand","Raymond Buch","Sanjit Chand","Hunter Lopez","Adrian Barton","Tom Ashbrook","Christopher Martinez","Keith Dawkins","Andy Reiter","Daniel Raglin"],"xaxis":"x","y":[8981.323900000001,6976.0959,5757.411899999999,5622.4292,5444.8054999999995,4703.7883,3899.8903999999998,3038.6254,2884.6208,2869.076],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"co ...

# %% [markdown]
# ### Task 4: Data Exploration: Place (location) Aspect

# %% [markdown]
# Let's analyze the profits gained in different states in the US

# %%
geo_data = data.groupby("State")["Profit"].sum().reset_index()
geo_data
# Out:
#                    State      Profit
# 0                Alabama   5786.8253
# 1                Arizona  -3427.9246
# 2               Arkansas   4008.6871
# 3             California  76381.3871
# 4               Colorado  -6527.8579
# 5            Connecticut   3511.4918
# 6               Delaware   9977.3748
# 7   District of Columbia   1059.5893
# 8                Florida  -3399.3017
# 9                Georgia  16250.0433
# 10                 Idaho    826.7231
# 11              Illinois -12607.8870
# 12               Indiana  18382.9363
# 13                  Iowa   1183.8119
# 14                Kansas    836.4435
# 15              Kentucky  11199.6966
# 16             Louisiana   2196.1023
# 17                 Maine    454.4862
# 18              Maryland   7031.1788
# 19         Massachusetts   6785.5016
# 20              Michigan  24463.1876
# 21             Minnesota  10823.1874
# 22           Mississippi   3172.9762
# 23              Missouri   6436.2105
# 24               Montana   1833.3285
# 25              Nebraska   2037.0942
# 26                Nevada   3316.7659
# 27         New Hampshire   1706.5028
# 28            New Jersey   9772.9138
# 29            New Mexico   1157.1161
# 30              New York  74038.5486
# 31        North Carolina  -7490.9122
# 32          North Dakota    230.1497
# 33                  Ohio -16971.3766
# 34              Oklahoma   4853.9560
# 35                Oregon  -1190.4705
# 36          Pennsylvania -15559.9603
# 37          Rhode Island   7285.6293
# 38        South Carolina   1769.0566
# 39          South Dakota    394.8283
# 40             Tennessee  -5341.6936
# 41                 Texas -25729.3563
# 42                  Utah   2546.5335
# 43               Vermont   2244.9783
# 44              Virginia  18597.9504
# 45            Washington  33402.6517
# 46         West Virginia    185.9216
# 47             Wisconsin   8401.8004
# 48               Wyoming    100.1960

# %% [markdown]
# ### Let's create a choropleth map
# Plotly uses abbreviated two-letter postal codes for state locations so it will be necessary to create a dictionary that contains conversions of the full names of states into abbreviations.

# %%
state_codes = {
        'Alabama': 'AL',
        'Alaska': 'AK',
        'Arizona': 'AZ',
        'Arkansas': 'AR',
        'California': 'CA',
        'Colorado': 'CO',
        'Connecticut': 'CT',
        'Delaware': 'DE',
        'District of Columbia': 'DC',
        'Florida': 'FL',
        'Georgia': 'GA',
        'Hawaii': 'HI',
        'Idaho': 'ID',
        'Illinois': 'IL',
        'Indiana': 'IN',
        'Iowa': 'IA',
        'Kansas': 'KS',
        'Kentucky': 'KY',
        'Louisiana': 'LA',
        'Maine': 'ME',
        'Maryland': 'MD',
        'Massachusetts': 'MA',
        'Michigan': 'MI',
        'Minnesota': 'MN',
        'Mississippi': 'MS',
        'Missouri': 'MO',
        'Montana': 'MT',
        'Nebraska': 'NE',
        'Nevada': 'NV',
        'New Hampshire': 'NH',
        'New Jersey': 'NJ',
        'New Mexico': 'NM',
        'New York': 'NY',
        'North Carolina': 'NC',
        'North Dakota': 'ND',
        'Ohio': 'OH',
        'Oklahoma': 'OK',
        'Oregon': 'OR',
        'Pennsylvania': 'PA',
        'Rhode Island': 'RI',
        'South Carolina': 'SC',
        'South Dakota': 'SD',
        'Tennessee': 'TN',
        'Texas': 'TX',
        'Utah': 'UT',
        'Vermont': 'VT',
        'Virginia': 'VA',
        'Washington': 'WA',
        'West Virginia': 'WV',
        'Wisconsin': 'WI',
        'Wyoming': 'WY'
}

# %% [markdown]
# let's map the abbreviated two-letter postal codes to the State column

# %%
geo_data.State = geo_data.State.map(state_codes)

# %%
geo_data
# Out:
#    State      Profit
# 0     AL   5786.8253
# 1     AZ  -3427.9246
# 2     AR   4008.6871
# 3     CA  76381.3871
# 4     CO  -6527.8579
# 5     CT   3511.4918
# 6     DE   9977.3748
# 7     DC   1059.5893
# 8     FL  -3399.3017
# 9     GA  16250.0433
# 10    ID    826.7231
# 11    IL -12607.8870
# 12    IN  18382.9363
# 13    IA   1183.8119
# 14    KS    836.4435
# 15    KY  11199.6966
# 16    LA   2196.1023
# 17    ME    454.4862
# 18    MD   7031.1788
# 19    MA   6785.5016
# 20    MI  24463.1876
# 21    MN  10823.1874
# 22    MS   3172.9762
# 23    MO   6436.2105
# 24    MT   1833.3285
# 25    NE   2037.0942
# 26    NV   3316.7659
# 27    NH   1706.5028
# 28    NJ   9772.9138
# 29    NM   1157.1161
# 30    NY  74038.5486
# 31    NC  -7490.9122
# 32    ND    230.1497
# 33    OH -16971.3766
# 34    OK   4853.9560
# 35    OR  -1190.4705
# 36    PA -15559.9603
# 37    RI   7285.6293
# 38    SC   1769.0566
# 39    SD    394.8283
# 40    TN  -5341.6936
# 41    TX -25729.3563
# 42    UT   2546.5335
# 43    VT   2244.9783
# 44    VA  18597.9504
# 45    WA  33402.6517
# 46    WV    185.9216
# 47    WI   8401.8004
# 48    WY    100.1960

# %%
px.choropleth(geo_data, locations="State", color="Profit", locationmode="USA-states", scope= "usa", color_continuous_scale = "Blugrn", title="Profit Gained by State")
#color_continuous_scale = "Blugrn" --- changing the color
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.32.0.min.js"></script>                <div id="f21a186c-f73a-429d-8afe-fd5fa841b120" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f21a186c-f73a-429d-8afe-fd5fa841b120")) {                    Plotly.newPlot(                        "f21a186c-f73a-429d-8afe-fd5fa841b120",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"State=%{location}\u003cbr\u003eProfit=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","locationmode":"USA-states","locations":["AL","AZ","AR","CA","CO","CT","DE","DC","FL","GA","ID","IL","IN","IA","KS","KY","LA","ME","MD","MA","MI","MN","MS","MO","MT","NE","NV","NH","NJ","NM","NY","NC","ND","OH","OK","OR","PA","RI","SC","SD","TN","TX","UT","VT","VA","WA","WV","WI","WY"],"name":"","z":[5786.8253,-3427.9246,4008.6871,76381.3871,-6527.8579,3511.4918,9977.3748,1059.5893,-3399.3017,16250.043300000001,826.7231,-12607.887,18382.9363,1183.8119,836.4435,11199.6966,2196.1023,454.4862,7031.1788,6785.5016,24463.1876,10823.187399999999,3172.9762,6436.2105,1833.3285,2037.0942,3316.7659000000003,1706.5028,9772.9138,1157.1161,74038.5486,-7490.912200000001,230.1497,-16971.3766,4853.956,-1190.4705,-15559.9603,7285.6293,1769.0566,394.8283,-5341.6936,-25729.3563,2546.5335,2244.9782999999998,18597.9504,33402.6517,185.9216,8401.8004,100.196],"type":"choropleth"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0 ...

# %% [markdown]
# Where the color is getting darker, we see higher profit. We can see that "California" and "New York" has highest profit

# %% [markdown]
# Exercise: Create a choropleth map to visualize the profit gained by selling technology(Category=technology) products in different states.

# %%
ex_data = data[data["Category"] == "Technology"]
ex_geo_data = ex_data.groupby("State")["Profit"].sum().reset_index()
px.choropleth(ex_geo_data,
              locations=ex_geo_data.State.map(state_codes), color="Profit",
              locationmode="USA-states", scope= "usa",
              color_continuous_scale = "Pubu", title="Profit Gained by State")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.32.0.min.js"></script>                <div id="1b3ff504-0311-4c05-a137-8dc0c0b982f3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1b3ff504-0311-4c05-a137-8dc0c0b982f3")) {                    Plotly.newPlot(                        "1b3ff504-0311-4c05-a137-8dc0c0b982f3",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"locations=%{location}\u003cbr\u003eProfit=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","locationmode":"USA-states","locations":["AL","AZ","AR","CA","CO","CT","DE","DC","FL","GA","ID","IL","IN","IA","KS","KY","LA","ME","MD","MA","MI","MN","MS","MO","MT","NE","NV","NH","NJ","NM","NY","NC","OH","OK","OR","PA","RI","SC","SD","TN","TX","UT","VT","VA","WA","WI"],"name":"","z":[3297.8029,112.50119999999997,1261.4384,29470.0368,-3471.5845,780.9336,6239.0508,648.5624,530.8047999999999,4399.6597,92.09729999999999,4822.5592,11000.8773,318.3682,174.9866,4156.636399999999,1015.0152,251.0328,1322.8776,1755.7501,4782.3025,1018.8008,986.4024,3014.7267999999995,1523.0354000000002,961.5150000000001,512.8456,902.7073,4170.198,337.2828,42186.7856,-3583.304,-12649.9401,1580.9003,126.35640000000001,-3191.2216000000003,4598.012299999999,453.5875,133.8966,66.03370000000004,3291.429,581.7351,447.2863,7407.7544,15019.3435,2597.0697],"type":"choropleth"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921" ...

# %% [markdown]
# New York has highest profti by selling the technological products

# %% [markdown]
# ### Task 5: Data Exploration - Hierarchical Information about the products

# %%
product_data = data.groupby(["Category", "Sub-Category"])["Profit"].sum().reset_index()
product_data = product_data[product_data.Profit > 0]
product_data["Sales"] = "Any"
product_data
# Out:
#            Category Sub-Category      Profit Sales
# 1         Furniture       Chairs  26590.1663   Any
# 2         Furniture  Furnishings  13059.1436   Any
# 4   Office Supplies   Appliances  18138.0054   Any
# 5   Office Supplies          Art   6527.7870   Any
# 6   Office Supplies      Binders  30221.7633   Any
# 7   Office Supplies    Envelopes   6964.1767   Any
# 8   Office Supplies    Fasteners    949.5182   Any
# 9   Office Supplies       Labels   5546.2540   Any
# 10  Office Supplies        Paper  34053.5693   Any
# 11  Office Supplies      Storage  21278.8264   Any
# 13       Technology  Accessories  41936.6357   Any
# 14       Technology      Copiers  55617.8249   Any
# 15       Technology     Machines   3384.7569   Any
# 16       Technology       Phones  44515.7306   Any

# %%
px.sunburst(product_data, path=["Category", "Sub-Category"], values="Profit", title="Profit Gained by Product Category")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.32.0.min.js"></script>                <div id="37a721fc-be31-44fe-91ec-dc97ccaea8f3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("37a721fc-be31-44fe-91ec-dc97ccaea8f3")) {                    Plotly.newPlot(                        "37a721fc-be31-44fe-91ec-dc97ccaea8f3",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}\u003cbr\u003eProfit=%{value}\u003cbr\u003eparent=%{parent}\u003cbr\u003eid=%{id}\u003cextra\u003e\u003c\u002fextra\u003e","ids":["Technology\u002fAccessories","Office Supplies\u002fAppliances","Office Supplies\u002fArt","Office Supplies\u002fBinders","Furniture\u002fChairs","Technology\u002fCopiers","Office Supplies\u002fEnvelopes","Office Supplies\u002fFasteners","Furniture\u002fFurnishings","Office Supplies\u002fLabels","Technology\u002fMachines","Office Supplies\u002fPaper","Technology\u002fPhones","Office Supplies\u002fStorage","Furniture","Office Supplies","Technology"],"labels":["Accessories","Appliances","Art","Binders","Chairs","Copiers","Envelopes","Fasteners","Furnishings","Labels","Machines","Paper","Phones","Storage","Furniture","Office Supplies","Technology"],"name":"","parents":["Technology","Office Supplies","Office Supplies","Office Supplies","Furniture","Technology","Office Supplies","Office Supplies","Furniture","Office Supplies","Technology","Office Supplies","Technology","Office Supplies","","",""],"values":[41936.6357,18138.0054,6527.787,30221.7633,26590.1663,55617.8249,6964.1767,949.5182,13059.1436,5546.254,3384.7569,34053.5693,44515.7306,21278.8264,39649.3099,123679.90030000001,145454.9481],"type":"sunburst"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[ ...

# %%
px.sunburst(product_data, path=["Sales","Category", "Sub-Category"], values="Profit", title="Sales by Product Category")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.32.0.min.js"></script>                <div id="9fa5a7e2-9cc5-4f50-a1db-f2515bb8fe2f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9fa5a7e2-9cc5-4f50-a1db-f2515bb8fe2f")) {                    Plotly.newPlot(                        "9fa5a7e2-9cc5-4f50-a1db-f2515bb8fe2f",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}\u003cbr\u003eProfit=%{value}\u003cbr\u003eparent=%{parent}\u003cbr\u003eid=%{id}\u003cextra\u003e\u003c\u002fextra\u003e","ids":["Any\u002fTechnology\u002fAccessories","Any\u002fOffice Supplies\u002fAppliances","Any\u002fOffice Supplies\u002fArt","Any\u002fOffice Supplies\u002fBinders","Any\u002fFurniture\u002fChairs","Any\u002fTechnology\u002fCopiers","Any\u002fOffice Supplies\u002fEnvelopes","Any\u002fOffice Supplies\u002fFasteners","Any\u002fFurniture\u002fFurnishings","Any\u002fOffice Supplies\u002fLabels","Any\u002fTechnology\u002fMachines","Any\u002fOffice Supplies\u002fPaper","Any\u002fTechnology\u002fPhones","Any\u002fOffice Supplies\u002fStorage","Any\u002fFurniture","Any\u002fOffice Supplies","Any\u002fTechnology","Any"],"labels":["Accessories","Appliances","Art","Binders","Chairs","Copiers","Envelopes","Fasteners","Furnishings","Labels","Machines","Paper","Phones","Storage","Furniture","Office Supplies","Technology","Any"],"name":"","parents":["Any\u002fTechnology","Any\u002fOffice Supplies","Any\u002fOffice Supplies","Any\u002fOffice Supplies","Any\u002fFurniture","Any\u002fTechnology","Any\u002fOffice Supplies","Any\u002fOffice Supplies","Any\u002fFurniture","Any\u002fOffice Supplies","Any\u002fTechnology","Any\u002fOffice Supplies","Any\u002fTechnology","Any\u002fOffice Supplies","Any","Any","Any",""],"values":[41936.6357,18138.0054,6527.787,30221.7633,26590.1663,55617.8249,6964.1767,949.5182,13059.1436,5546.254,3384.7569,34053.5693,44515.7306,21278.8264,39649.3099,123679.90030000001,145454.9481,308784.1583],"type":"sunburst"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"tick ...

# %% [markdown]
# Here we see different product categories is mapped to different colors.
# We have technology, office, supplies and furniture the size of each arc is represenging the amount of the profit gained for each of the category or subcategory.
# we can see that, for example, technology has the highest amount of profit.
#
# By clicking on each category we get more information about their sub-category and see the different heirarchical level of data and the inner circle present the profit gained by any sort of product sold, but only the positive profit

# %%
# making tree map
px.treemap(product_data, path=["Sales","Category", "Sub-Category"], values="Profit", title="Profit Gained by Product Category")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.32.0.min.js"></script>                <div id="bea2987f-1727-45bf-9297-8fb5fd35eddf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bea2987f-1727-45bf-9297-8fb5fd35eddf")) {                    Plotly.newPlot(                        "bea2987f-1727-45bf-9297-8fb5fd35eddf",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}\u003cbr\u003eProfit=%{value}\u003cbr\u003eparent=%{parent}\u003cbr\u003eid=%{id}\u003cextra\u003e\u003c\u002fextra\u003e","ids":["Any\u002fTechnology\u002fAccessories","Any\u002fOffice Supplies\u002fAppliances","Any\u002fOffice Supplies\u002fArt","Any\u002fOffice Supplies\u002fBinders","Any\u002fFurniture\u002fChairs","Any\u002fTechnology\u002fCopiers","Any\u002fOffice Supplies\u002fEnvelopes","Any\u002fOffice Supplies\u002fFasteners","Any\u002fFurniture\u002fFurnishings","Any\u002fOffice Supplies\u002fLabels","Any\u002fTechnology\u002fMachines","Any\u002fOffice Supplies\u002fPaper","Any\u002fTechnology\u002fPhones","Any\u002fOffice Supplies\u002fStorage","Any\u002fFurniture","Any\u002fOffice Supplies","Any\u002fTechnology","Any"],"labels":["Accessories","Appliances","Art","Binders","Chairs","Copiers","Envelopes","Fasteners","Furnishings","Labels","Machines","Paper","Phones","Storage","Furniture","Office Supplies","Technology","Any"],"name":"","parents":["Any\u002fTechnology","Any\u002fOffice Supplies","Any\u002fOffice Supplies","Any\u002fOffice Supplies","Any\u002fFurniture","Any\u002fTechnology","Any\u002fOffice Supplies","Any\u002fOffice Supplies","Any\u002fFurniture","Any\u002fOffice Supplies","Any\u002fTechnology","Any\u002fOffice Supplies","Any\u002fTechnology","Any\u002fOffice Supplies","Any","Any","Any",""],"values":[41936.6357,18138.0054,6527.787,30221.7633,26590.1663,55617.8249,6964.1767,949.5182,13059.1436,5546.254,3384.7569,34053.5693,44515.7306,21278.8264,39649.3099,123679.90030000001,145454.9481,308784.1583],"type":"treemap"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks ...

# %% [markdown]
# The map tree uses same idea, but with uses different rectangles to present values. The small rectangles represents the subcategories and bigger one represents the category and the biggest one is representing the any sort of product that we have.
# By clicking on each category we can look at its cubcategories

# %% [markdown]
# ### Task 6: Data Exploration: Product Sales information (Sales, Quantity, Profit)

# %%
data.head()
# Out:
#      Order Date  Customer Name         State         Category Sub-Category  \
# 7980 2014-01-03  Darren Powers         Texas  Office Supplies        Paper
# 739  2014-01-04  Phillina Ober      Illinois  Office Supplies       Labels
# 740  2014-01-04  Phillina Ober      Illinois  Office Supplies      Storage
# 741  2014-01-04  Phillina Ober      Illinois  Office Supplies      Binders
# 1759 2014-01-05     Mick Brown  Pennsylvania  Office Supplies          Art
#
#                                            Product Name    Sales  Quantity  \
# 7980  Message Book, Wirebound, Four 5 1/2" X 4" Form...   16.448         2
# 739                                           Avery 508   11.784         3
# 740                       SAFCO Boltless Steel Shelving  272.736         3
# 741          GBC Standard Plastic Binding Systems Combs    3.540         2
# 1759  Avery Hi-Liter EverBold Pen Style Fluorescent ...   19.536         3
#
#        Profit  Year  Month  Day
# 7980   5.5512  2014      1    3
# 739    4.2717  2014      1    4
# 740  -64.7748  2014      1    4
# 741   -5.4870  2014      1    4
# 1759   4.8840  2014      1    5

# %% [markdown]
# Distribution Analysis on **Quantity** column

# %% [markdown]
# Let's check the statistical summary of the column

# %%
data.Quantity.describe()
# Out:
# count    9994.000000
# mean        3.789574
# std         2.225110
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         5.000000
# max        14.000000
# Name: Quantity, dtype: float64

# %% [markdown]
# Here we can see that with mean = 3.7 and standard deviation = 2.7, most of our data values in the quantity column are aroudn mean value.
# By looking at the maximum value, we can say that there are outliers, because it is far from the mean value.

# %%
px.histogram(data, x="Quantity", title="Quantity Distribution")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.32.0.min.js"></script>                <div id="4b92b78a-c2e5-4342-8f31-bacb9bea95f2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4b92b78a-c2e5-4342-8f31-bacb9bea95f2")) {                    Plotly.newPlot(                        "4b92b78a-c2e5-4342-8f31-bacb9bea95f2",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Quantity=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[2,3,3,2,3,2,9,2,3,2,4,4,1,3,3,7,2,3,1,1,2,6,3,5,2,5,7,2,6,3,3,6,4,5,3,6,3,2,4,10,4,5,5,3,5,2,1,3,4,3,2,3,5,3,1,3,7,2,4,7,3,3,6,2,2,2,3,13,3,8,3,2,1,4,3,1,2,2,2,6,2,5,5,3,2,3,4,2,5,1,4,2,7,4,2,2,1,3,2,3,2,3,6,3,2,2,2,3,3,5,3,2,14,2,5,3,4,2,5,3,3,3,4,3,4,6,2,6,5,3,3,3,3,3,6,5,2,3,1,4,5,3,3,1,3,3,8,5,3,5,2,3,3,2,6,2,6,5,5,1,2,3,3,4,3,2,3,3,5,6,2,3,14,3,4,2,6,4,1,12,2,2,1,2,2,4,1,3,3,3,2,3,2,2,6,3,7,6,10,6,4,2,4,3,7,7,4,3,1,2,4,3,6,7,4,3,2,2,3,10,4,2,3,3,4,3,5,3,3,3,3,4,3,5,7,3,2,1,5,3,5,3,4,2,3,6,2,2,5,7,2,2,4,6,5,3,2,4,2,4,3,1,3,3,7,2,7,3,3,5,5,5,2,5,2,7,1,2,1,2,7,2,4,2,2,4,2,3,5,7,5,7,2,2,3,3,4,1,2,2,6,5,2,4,7,7,2,5,1,1,3,6,5,2,7,4,2,2,3,3,3,
,1,2,5,2,3,5,3,5,4,2,4,3,2,1,3,2,2,5,2,10,4,1,5,2,5,3,3,6,6,7,6,7,3,3,2,1,3,2,2,3,1,2,9,6,5,2,3,2,4,2,2,6,5,4,3,1,2,2,3,2,3,3,9,3,9,3,3,5,2,3,2,5,2,3,4,4,2,1,3,3,5,5,2,9,5,4,3,2,3,4,3,4,2,8,2,2,2,1,5,11,3,3,3,1,2,4,6,2,6,2,3,5,2,2,4,3,8,9,3,4,9,2,2,2,1,4,2,3,2,2,11,4,6,5,1,1,3,3,7,6,6,1,1,2,2,6,1,2,2,3,3,2,3,3,2,4,3,3,3,2,1,3,5,4,5,2,5,5,2,5,2,2,3,10,5,3,4,2,1,3,7,5,6,1,2,7,7,3,2,2,5,3,1,4,1,11,2,4,2,1,5,2,4,4,1,3,2,4,5,3,5,2,2,3,7,9,3,13,5,5,4,4,4,1,2,2,3,3,3,2,5,6,2,6,6,5,6,4,3,1,6,3,6,3,1,3,5,4,4,3,1,1,1,3,3,5,3,4,3,1,4,4,4,3,2,3,4,3,3,5,4,2,3,6,2,2,5,2,2,2,2,6,3,3,5,2,2,2,3,5,1,9,3,8,2,13,2,3,8,4,5,3,5,3,3,2,3,6,5,12,3,2,3,2,5,3,3,2,3,9,4,3,3,7,6,6,2,1,7,2,2,10,9,2,3,3,7,3,4,6,2,2,2,3,4,2,2,1,4,6,3,5,4,3,3,4,7,1,1,4,2,5,6,5,3,6,2,2,2,6,3,2,3,6,7,3,4,4,7,5,3,3,4,3,3,3,2,4,5,9,6,7,2,3,2,3,3,3,3,8,8,8,5,1,4,2,5,3,5,4,9,2,1,4,2,4,3,7,1,1,1,2,2,2,8,5,6,2,3,5,2,3,6,3,3,1,4,1,2,3,7,4,4,2,10,7,3,2,5,3,9,4,3,2,3,3,2,2,4,5,6,2,3,5,4,2,3 ...

# %% [markdown]
# Here we can see that the most of the products, most of the sales record, has been recorded with the quantity two so there are 2409 with the quantity.
# So three and two are the most common values in the column.
# Also we can see that there is a tail on the right side of the histogram, the distirbution of this column is right skewed and it means that there are some outliers on the right side of the histogram.
# By looking at the tail of the graph we can see that in the quantity column there are some values that are very accurate. For example, we have quantity 14*29 times happen or quantity 13*27 times.
# The values on the tail are very rare in our distribution, so we can call them outliers.

# %% [markdown]
# Exercise: Apply distribution analysis using boxplot to the **Profit** column. using statistical summary and a box plot.

# %%
px.box(data, y="Quantity", title="Quantity Distribution")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.32.0.min.js"></script>                <div id="94ffbcfd-2885-46b6-8717-effe47186337" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("94ffbcfd-2885-46b6-8717-effe47186337")) {                    Plotly.newPlot(                        "94ffbcfd-2885-46b6-8717-effe47186337",                        [{"alignmentgroup":"True","hovertemplate":"Quantity=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x0":" ","xaxis":"x","y":

# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.32.0.min.js"></script>                <div id="4e750466-12d8-44a8-96b1-a6ffd8a4d9db" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4e750466-12d8-44a8-96b1-a6ffd8a4d9db")) {                    Plotly.newPlot(                        "4e750466-12d8-44a8-96b1-a6ffd8a4d9db",                        [{"alignmentgroup":"True","hovertemplate":"Year=%{x}\u003cbr\u003eQuantity=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":[2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014, ...

# %% [markdown]
# Here we see four different box plots realted to the sales in the year of 2014, 15, 16, 17.
# so for each year we have a different box plot for quantoty column.

# %%
px.box(data, y="Quantity", x="Category", color="Year", title="Quantity Distribution")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.32.0.min.js"></script>                <div id="d8dd7640-69b7-4147-bfe8-66a2d75f2fc6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d8dd7640-69b7-4147-bfe8-66a2d75f2fc6")) {                    Plotly.newPlot(                        "d8dd7640-69b7-4147-bfe8-66a2d75f2fc6",                        [{"alignmentgroup":"True","hovertemplate":"Year=2014\u003cbr\u003eCategory=%{x}\u003cbr\u003eQuantity=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2014","marker":{"color":"#636efa"},"name":"2014","notched":false,"offsetgroup":"2014","orientation":"v","showlegend":true,"x":["Office Supplies","Office Supplies","Office Supplies","Office Supplies","Office Supplies","Office Supplies","Furniture","Office Supplies","Office Supplies","Technology","Technology","Office Supplies","Office Supplies","Office Supplies","Furniture","Office Supplies","Office Supplies","Technology","Furniture","Office Supplies","Furniture","Office Supplies","Office Supplies","Office Supplies","Office Supplies","Office Supplies","Office Supplies","Office Supplies","Furniture","Furniture","Office Supplies","Technology","Furniture","Technology","Office Supplies","Furniture","Technology","Office Supplies","Office Supplies","Office Supplies","Office Supplies","Office Supplies","Furniture","Furniture","Office Supplies","Office Supplies","Office Supplies","Office Supplies","Furniture","Office Supplies","Office Supplies","Furniture","Office Supplies","Furniture","Office Supplies","Office Supplies","Office Supplies","Furniture","Office Supplies","Technology","Furniture","Office Supplies","Office Supplies","Office Supplies","Furniture","Technology","Furniture","Technology","Office Supplies","Office Supplies","Furniture","Office Supplies","Office Supplies","Office Supplies","Furniture","Office Supplies","Office Supplies","Office Supplies","Furniture","Technology","Office Supplies","Technology","Office Supplies","Office Supplies","Office Supplies","Office Supplies","Office Supplies","Office Supplies","Technology","Technology","Office Supplies","Office Supplies","Technology","Office Supplies","Furniture","Office Supplies","Furniture","Office Supplies","Office Supplies","Furniture","Office Supplies","Office Supplies","Furniture","Technology","Furniture","Office Supplies","Office Supplies","Technology","Office Supplies","Office Supplies","Office Supplies","Office Supplies","Office Supplies","Office Supplies","Furniture","Technology","Furniture","Office Supplies","Office Supplies","Office Supplies","Office Supplies","Office Supplies","Office Supplies","Office Supplies","Office Supplies","Furniture","Furniture","Furniture","Office Supplies","Technology","Furniture","Office Supplies","Office Supplies","Office Supplies","Furniture","Office Supplies","Office Supplies","Technology","Office Supplies","Office Supplies","Furniture","Office Supplies","Furniture","Technology","Office Supplies","Office Supplies","Office Supplies","Office Supplies","Office Supplies","Office Supplies","Office Supplies","Office Supplies","Technology","Office Supplies","Office Supplies","Furniture","Furniture","Office Supplies","Office Supplies","Furniture","Office Supplies","Office Supplies","Office Supplies","Office Supplies","Office Supplies","Office Supplies","Office Supplies","Office Supplies","Furniture","Office Supplies","Technology","Office Supplies","Office Supplies","Technology","Furniture","Office Supplies","Office Supplies","Office Supplies","Office Supplies","Technology","Office Supplies","Office Supplies","Office Supplies","Technology","Office Supplies","Office Supplies","Office Supplies","Furniture","Office Supplies","Office Supplies","Technology","Office Supplies","Office Supplies","Office Supplies","Office Supplies","Furnit ...

# %% [markdown]
# Here we see each product category with different box plot and shows different color related to each category for specific year.
# Distribution based upon each year and each category at the same time.

# %% [markdown]
# Task: Apply distribution analysis the Profit column, using statical summary and a box plot

# %%
data.Profit.describe()
# Out:
# count    9994.000000
# mean       28.656896
# std       234.260108
# min     -6599.978000
# 25%         1.728750
# 50%         8.666500
# 75%        29.364000
# max      8399.976000
# Name: Profit, dtype: float64

# %% [markdown]
# Here we can see thet:
# - We have negative values (the min value = - 6599)
# - The mean value is 28.65
# - The max value is 8399
# - There are outliers in the both sides

# %%
px.box(data, y="Profit", title="Profit Distribution")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2
.3055,20.853,-12.098,-10.116,1.0584,98.4802,-1.3083,13.9972,-0.5964,14.8344,-13.8278,252.588,5.5536,14.8,3.0576,2.6784,46.1968,7.128,9.352,293.9804,40.274,10.465,5.58,57.5928,22.4316,9.3312,23.808,2.3521,6.3504,2.245,9.072,9.302,42.9914,3.9072,56.5264,7.5768,7.476,18.09,8.4071,26.6304,4.5837,20.6946,83.281,6.3504,6.6584,3.7224,23.7684,2.034,18.447,131.9868,111.1035,-36.1116,-35.928,21.897,15.6332,-2.1896,9.3312,26.6304,12.9129,2.7776,50.2425,27.9936,163.787,60.2553,0.8288,-94.6605,-11.8256,6.8904,139.986,2.4898,316.1392,3.6288,24.3824,9.2386,91.3248,265.4232,41.993,81.5949,2.3328,3.3544,38.3572,6.5569,16.2688,-18.147,15.552,94.0702,3.6018,1.116,8.3916,-407.976,10.0724,31.0184,76.9816,9.768,1.008,-18.1176,50.4063,28.497,97.1892,3.8048,3.5475,3.6022,26.649,26.703,34.2144,5.605,-131.951,27.5632,-95.67,0.0,5.5755,121.4416,3.3453,22.9877,-1.7514,-12.0588,-12.0588,-5.2416,7.8176,3.6288,0.546,63.6825,37.797,78.5088,148.704,6.206,5.715,5.796,23.028,2.0322,57.5928,-37.7332,9.387,125.997,129.3786,1.4952,1.512,2.5056,-1.249,5.1948,5.9364,8.6112,70.198,12.99,16.2486,45.487,214.76,1.9602,89.997,10.3488,3.9498,14.5638,9.8856,2.838,1.8468,19.0344,3.8976,21.06,5.346,16.6568,3.9592,-9.1335,11.5432,1.9024, ...

# %% [markdown]
# Here we can see that the plot is very wierd and there are many outliers

# %% [markdown]
# ### Task 7: What Is Confirmatory Data Analysis (CDA)?

# %% [markdown]
# By definition, Confirmatory Data Analysis is the process of using statistical summary and graphical representations to evaluate the validity of an assumption about the data at hand.
#
# We have the following assumption about our data, and we are going to use different exploration techniques we learned in the previous tasks to validate them.
#
#     Assumption 1 - Every summer technology products have the highest sale quantity compared to other product categories.
#     Assumption 2- In New York, there are many big companies, therefore, office supplies product has
#     the highest sale quantity compared to other big states such as Texas, Illinois, and California.

# %% [markdown]
# Assumption 1 - Every summer technology products have the highest sale quantity compared to other product categories.

# %%
seasons = {
    1 : "Winter",
    2 : "Spring",
    3 : "Summer",
    4 : "Fall"
}

# %% [markdown]
# Creating **Season** column

# %%
data["Season"] = data.Month.astype(int) % 12 // 3 + 1
data.Season=data.Season.map(seasons)
data.head()
# Out:
#      Order Date  Customer Name         State         Category Sub-Category  \
# 7980 2014-01-03  Darren Powers         Texas  Office Supplies        Paper
# 739  2014-01-04  Phillina Ober      Illinois  Office Supplies       Labels
# 740  2014-01-04  Phillina Ober      Illinois  Office Supplies      Storage
# 741  2014-01-04  Phillina Ober      Illinois  Office Supplies      Binders
# 1759 2014-01-05     Mick Brown  Pennsylvania  Office Supplies          Art
#
#                                            Product Name    Sales  Quantity  \
# 7980  Message Book, Wirebound, Four 5 1/2" X 4" Form...   16.448         2
# 739                                           Avery 508   11.784         3
# 740                       SAFCO Boltless Steel Shelving  272.736         3
# 741          GBC Standard Plastic Binding Systems Combs    3.540         2
# 1759  Avery Hi-Liter EverBold Pen Style Fluorescent ...   19.536         3
#
#        Profit  Year  Month  Day  Season
# 7980   5.5512  2014      1    3  Winter
# 739    4.2717  2014      1    4  Winter
# 740  -64.7748  2014      1    4  Winter
# 741   -5.4870  2014      1    4  Winter
# 1759   4.8840  2014      1    5  Winter

# %% [markdown]
# Extracting data related to summer every year

# %%
summer_data = data[data.Season == "Summer"]
summer_data.head()
# Out:
#     Order Date  Customer Name       State         Category Sub-Category  \
# 245 2014-06-01  Dianna Wilson   Minnesota  Office Supplies      Storage
# 307 2014-06-01    Corey Roper  New Jersey  Office Supplies          Art
# 246 2014-06-01  Dianna Wilson   Minnesota  Office Supplies        Paper
# 247 2014-06-01  Dianna Wilson   Minnesota  Office Supplies   Appliances
# 248 2014-06-01  Dianna Wilson   Minnesota  Office Supplies        Paper
#
#                                           Product Name    Sales  Quantity  \
# 245                       Safco Steel Mobile File Cart   166.72         2
# 307  Boston Heavy-Duty Trimline Electric Pencil Sha...   289.20         6
# 246  Adams Telephone Message Book w/Frequently-Call...    47.88         6
# 247  Honeywell Enviracaire Portable HEPA Air Cleane...  1503.25         5
# 248                                          Xerox 205    25.92         4
#
#        Profit  Year  Month  Day  Season
# 245   41.6800  2014      6    1  Summer
# 307   83.8680  2014      6    1  Summer
# 246   23.9400  2014      6    1  Summer
# 247  496.0725  2014      6    1  Summer
# 248   12.4416  2014      6    1  Summer

# %% [markdown]
# Aggregating data based on Year, Category, and Season columns and summing up the Quantity

# %%
summer_data_agg = summer_data.groupby(["Year", "Category", "Season"])["Quantity"].sum().reset_index()
summer_data_agg
# Out:
#     Year         Category  Season  Quantity
# 0   2014        Furniture  Summer       343
# 1   2014  Office Supplies  Summer      1031
# 2   2014       Technology  Summer       306
# 3   2015        Furniture  Summer       386
# 4   2015  Office Supplies  Summer       959
# 5   2015       Technology  Summer       296
# 6   2016        Furniture  Summer       402
# 7   2016  Office Supplies  Summer      1406
# 8   2016       Technology  Summer       385
# 9   2017        Furniture  Summer       486
# 10  2017  Office Supplies  Summer      1638
# 11  2017       Technology  Summer       531

# %% [markdown]
# Let's visualize our result using a grouped bar chart

# %%
px.bar(summer_data_agg, x="Year", y="Quantity", color="Category", barmode="group", title="Summer Sales by Product Category")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.32.0.min.js"></script>                <div id="e536cf81-bf64-4c2f-b286-84e7b032cac1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e536cf81-bf64-4c2f-b286-84e7b032cac1")) {                    Plotly.newPlot(                        "e536cf81-bf64-4c2f-b286-84e7b032cac1",                        [{"alignmentgroup":"True","hovertemplate":"Category=Furniture\u003cbr\u003eYear=%{x}\u003cbr\u003eQuantity=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Furniture","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Furniture","offsetgroup":"Furniture","orientation":"v","showlegend":true,"textposition":"auto","x":[2014,2015,2016,2017],"xaxis":"x","y":[343,386,402,486],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Category=Office Supplies\u003cbr\u003eYear=%{x}\u003cbr\u003eQuantity=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Office Supplies","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Office Supplies","offsetgroup":"Office Supplies","orientation":"v","showlegend":true,"textposition":"auto","x":[2014,2015,2016,2017],"xaxis":"x","y":[1031,959,1406,1638],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"